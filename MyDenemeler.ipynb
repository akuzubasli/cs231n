# %%
import numpy as np
x = np.arange(8.0)

# %%
print(x)
# Out:
# [0. 1. 2. 3. 4. 5. 6. 7.]

# %%
x = np.arange(1,8,1)

# %%
print(x)
# Out:
# [1 2 3 4 5 6 7]

# %%
x = np.arange(1,8.1,1)

# %%
x
# Out:
# array([1., 2., 3., 4., 5., 6., 7., 8.])

# %%
print(x)
# Out:
# [1. 2. 3. 4. 5. 6. 7. 8.]

# %%
x = np.array_split(x,2)

# %%
x
# Out:
# [array([1., 2., 3., 4.]), array([5., 6., 7., 8.])]

# %%
x = np.array(x)

# %%
x
# Out:
# array([[1., 2., 3., 4.],
#        [5., 6., 7., 8.]])

# %%
x = xtange(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-8da28a24ae9c> in <module>()
# ----> 1 x = xtange(5)
#
# NameError: name 'xtange' is not defined

# %%
x = xrange(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-2e98ae2803d7> in <module>()
# ----> 1 x = xrange(5)
#
# NameError: name 'xrange' is not defined

# %%
for i in xrange(5):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-2461b73d7b01> in <module>()
# ----> 1 for i in xrange(5):
#       2     print(i)
#
# NameError: name 'xrange' is not defined

# %%
x = range(5)

# %%
x
# Out:
# range(0, 5)

# %%
for x in xrange(5):
    print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-32fef02c1029> in <module>()
# ----> 1 for x in xrange(5):
#       2     print(x)
#
# NameError: name 'xrange' is not defined

# %%
for x in range(5):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
n = 3
combinat = [x for x in range(5) if x != n]

# %%
combinat
# Out:
# [0, 1, 2, 4]

# %%
combinat = [x for x in range(5)]

# %%
combinat
# Out:
# [0, 1, 2, 3, 4]

# %%
animals = ['cat', 'dog', 'monkey']

# %%
print(enumerate(animals))

# %%
animals = ['cat', 'dog', 'monkey']
for animal in enumerate(animals):
    print('#%d: %s' % (animal))
# Out:
# #0: cat
# #1: dog
# #2: monkey

# %%
animal_list ={}

# %%
animal_list.append(enumerate(animals))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-0e6cce3ecb4a> in <module>()
# ----> 1 animal_list.append(enumerate(animals))
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
print(type(enumerate(animals)))
# Out:
# <class 'enumerate'>

# %%
print(animal_list)
# Out:
# {1: 'cat', 2: 'dog', 3: 'monkey'}

# %%
print(animal_list[2])
# Out:
# monkey

# %%
from scipy.misc import imread, imsave, imresize
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
img = imread("./cs231n/cat.jpg")
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
from scipy.misc import imageio.imread
# Out:
#   File "<ipython-input-3-7527a80bbcbd>", line 1
#     from scipy.misc import imageio.imread
#                                   ^
# SyntaxError: invalid syntax

# %%
from scipy.misc import imageio.imread
# Out:
#   File "<ipython-input-4-7527a80bbcbd>", line 1
#     from scipy.misc import imageio.imread
#                                   ^
# SyntaxError: invalid syntax

# %%
from imageio.imread import imread
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-22a39c2fb108> in <module>()
# ----> 1 from imageio.imread import imread
#
# ImportError: No module named 'imageio'

# %%
img = imageio.imread("./cs231n/cat.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3dbc05de31a0> in <module>()
# ----> 1 img = imageio.imread("./cs231n/cat.jpg")
#
# NameError: name 'imageio' is not defined

# %%
from scipy.misc import imageio
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-ea510637c880> in <module>()
# ----> 1 from scipy.misc import imageio
#
# ImportError: cannot import name 'imageio'

# %%
from scipy.misc import imread, imsave, imresize

# Read an JPEG image into a numpy array
img = imread('assets/cat.jpg')
print(img.dtype, img.shape)  # Prints "uint8 (400, 248, 3)"
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-85128adbd6cf> in <module>()
#       2
#       3 # Read an JPEG image into a numpy array
# ----> 4 img = imread('assets/cat.jpg')
#       5 print(img.dtype, img.shape)  # Prints "uint8 (400, 248, 3)"
#
# ~/.local/lib/python3.5/site-packages/numpy/lib/utils.py in newfunc(*args, **kwds)
#      99             """`arrayrange` is deprecated, use `arange` instead!"""
#     100             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# --> 101             return func(*args, **kwds)
#     102
#     103         newfunc = _set_function_name(newfunc, old_name)
#
# ...

# %%
from scipy.misc import imread, imsave, imresize

# Read an JPEG image into a numpy array
img = imread('./cs231n/cat.jpg')
print(img.dtype, img.shape)  # Prints "uint8 (400, 248, 3)"
# Out:
# uint8 (400, 248, 3)
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   after removing the cwd from sys.path.

# %%
import numpy as np
from scipy.misc import imread, imresize
import matplotlib.pyplot as plt

img = imread('assets/cat.jpg')
img_tinted = img * [1, 0.95, 0.9]

# Show the original image
plt.subplot(1, 2, 1)
plt.imshow(img)

# Show the tinted image
plt.subplot(1, 2, 2)

# A slight gotcha with imshow is that it might give strange results
# if presented with data that is not uint8. To work around this, we
# explicitly cast the image to uint8 before displaying it.
plt.imshow(np.uint8(img_tinted))
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-1c820af4d25f> in <module>()
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 img = imread('assets/cat.jpg')
#       6 img_tinted = img * [1, 0.95, 0.9]
#       7
#
# ~/.local/lib/python3.5/site-packages/numpy/lib/utils.py in newfunc(*args, **kwds)
#      99             """`arrayrange` is deprecated, use `arange` instead!"""
#     100             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# --> 101             return func(*args, **kwds)
#     102
#     103         newfunc = _set_function_name(newfunc, old_name)
#
# ...

# %%
import numpy as np
from scipy.misc import imread, imresize
import matplotlib.pyplot as plt

img = imread('./cs231n/cat.jpg')
img_tinted = img * [1, 0.95, 0.9]

# Show the original image
plt.subplot(1, 2, 1)
plt.imshow(img)

# Show the tinted image
plt.subplot(1, 2, 2)

# A slight gotcha with imshow is that it might give strange results
# if presented with data that is not uint8. To work around this, we
# explicitly cast the image to uint8 before displaying it.
plt.imshow(np.uint8(img_tinted))
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """

# %%
from imageio import imread

# %%
img = imread('cs231n/cat.jpg')

# %%
plt.imshow(img)

# %%
plt.Subplot(2,1,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-e73087e48444> in <module>()
# ----> 1 plt.Subplot(2,1,1)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      66                 # num - 1 for converting from MATLAB to python indexing
#      67         else:
# ---> 68             raise ValueError('Illegal argument(s) to subplot: %s' % (args,))
#      69
#      70         self.update_params()
#
# ValueError: Illegal argument(s) to subplot: (1, 1)

# %%
plt.subplot(2,1,1)

# %%
plt.imshow(img)

# %%
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(img*[0.9,1,0.95])
